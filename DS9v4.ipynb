# %% [markdown]
# <a href="https://colab.research.google.com/github/okana2ki/intro-to-DS/blob/main/DS9v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colabで開いたら、まず、Googleアカウントでログインします。続いて、↑上部の**「ドライブにコピー」をクリック**して下さい。Googleドライブの [マイドライブ > Colab Notebooks] に保存され、その後加えた変更がそこに自動保存されるようになります。Googleアカウントは、大学から付与されたアカウントでも個人のGoogleアカウントでもどちらでも大丈夫です。
#
# ヘッダーに表示されるはずの「ドライブにコピー」が表示されてない場合は、画面上部右端の「v」アイコンをクリックして、**ヘッダーの表示／非表示**を切り替えて下さい。
#
# スマホの場合は、左上の3本線を押して、「ファイル」-「ドライブにコピーを保存」のはず。

# %% [markdown]
# # １．Google Colabの使い方
# [ここ](https://colab.research.google.com/notebooks/intro.ipynb?hl=ja)や[ここ](https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Ftutorials.chainer.org%2Fja%2F01_Welcome_to_Chainer_Tutorial.html)を参照。

# %% [markdown]
# # ２．Gemini (Colab AI) の使い方
# * （期間限定の可能性がありますが）無料版のGoogle Colabでも、Geminiが使えて便利です。
# * Pythonに対応しています。
# * Googleアカウントでログインした状態で、**PCで**このコラボ・ノートブックを開くとAIが手伝ってくれます。
# * Googleアカウントについての説明やアカウントの作成の仕方は、[ここ](https://support.google.com/accounts/answer/27441?hl=ja)を参照
# * Googleアカウントは、Google Workspace for Educationのアカウント（例：産経大で提供されているGoogleアカウント）でも個人のGoogleアカウント（13歳以上）でもどちらでも大丈夫です。
# * **スマホ**はGemini (Colab AI)に対応していませんが、Androidの場合は、ブラウザ画面右上部の「縦に3つ点が並んだメニューアイコン」をタップし、「**PC版サイト**」をタップすると、PC版表示になるため見にくくはなりますが、Geminiが使えます。iPhone, iPadの場合は[ここ](https://atmarkit.itmedia.co.jp/ait/articles/1411/10/news130.html)を見てPC版サイトへの切り替え方を調べて下さい。
#
# * 「ツール」-「設定」-「AIアシスタント」で生成AI機能を使うかどうかを選択できる。
#
# * 仕様を伝えてコード生成を頼んだり、既存のコードに対する仕様変更を頼んだり、エラーメッセージを伝えてエラーの解説やデバッグをしてもらったり、コードの解説をしてもらったりできる。
#
# * 英語で応答が返ってきたときは、「日本語にして」などと依頼すると日本語で説明してくれる。
#
# Geminiの使い方（新しく作成したコードセルにコードを生成してもらう方法）：
#
# 1. 新しくコードセルを作成すると「コーディングを開始するか、AIで<u>生成</u>します。」と表示されるので、この「<u>生成</u>」のところをクリックする。
#
# 2. ノートブックの中央下部に対話窓が現れるので、生成して欲しいプログラムを言葉で指示すると、指示に沿ったコードがコードセル内に生成される。先頭に「－」が付いた赤地の行は削除される行を示し、先頭に「＋」が付いた緑地の行は追加される行を示す。
#
# 3. AIが提案してきたコードが良さそうであれば、対話窓の上の「承認して実行」をクリック；承認するだけなら「レ　許可」をクリック（その後、コードセルにマウスオンする（コードセル上にマウスカーソルを持ってくる）と左端に実行ボタンが現れるのでそれをクリック）；受け入れない場合は「×　キャンセル」をクリック。
#
# 4. 実行エラーが出た場合に表示される「エラーの修正」ボタンを押すと修正案が提示される。「エラーの説明」ボタンを押すとエラーが説明される。
#
# 5. 対話用ウィンドウの右上部の「×」を押すと対話ウィンドウを消すことができる；右上部の「パネルに移動」アイコンを押すと、対話ウィンドウは閉じられ、右側に対話パネルが開く；右上の３点メニューを開いて「新しいチャット」を始めることもできる。
#
# 6. 右側の対話パネルの右上の「ノートブックに移動」アイコンを押すと、対話パネルは閉じられ、ノートブックの中央下部に対話ウィンドウが開く。
#
# Geminiの使い方（今選択されているセルのすぐ下に、コードセルを作ってそこにコードを生成してもらう方法）：
#
# 1. 画面最下部中央の「Gemini」アイコンをクリックする。
#
# 2. 対話ウインドウまたは対話パネルが開くので、コード生成を依頼する。その時点で選択されているセルのすぐ下にコードセルが作られ、そこにコードが生成される。

# %% [markdown]
# # ３．最初の練習：電卓代わり
#
# * このセルは**テキストセル**で、文章を書く場所です。このセル内でダブルクリックすると左側のカラムで書き換えができるようになります。
# * 下記のセルは**コードセル**で、プログラムを書く場所です。簡単なPythonプログラムが記入してあります。セル内でクリックするとカーソルが現れ書き換えられるようになります。自由に書き換えてみて下さい。
# * コードセル左端の**再生ボタン**（マウスカーソルをセル上に置くと現れます）を押すとプログラムが実行されます。各セルを実行してみましょう。
# * 「ドライブにコピー」せずに、実行ボタンを押すと、「警告: このノートブックは Google が作成したものではありません。」というメッセージが出ますが、このノートブックは危険な内容は含まないので、「このまま実行」をクリックして実行して構いません。なお、「ドライブにコピー」した上で実行ボタンを押した場合は、この警告は出ません。

# %%
1 / 3

# %%
2 * (7 - 3)

# %%
2 ** 4  # 2の4乗

# %% [markdown]
# ↑ 「#」から右（緑色に表示されている部分）は、コメントで、プログラム実行時は無視されます。人が読んで理解しやすいようにコメントを書き添えます。

# %% [markdown]
# ## コードの説明を依頼する

# %%
a = 24
b = 8
print(a + b, a / b)

# %% [markdown]
# 説明の依頼方法その１
# * コードセルを選択する（コードセル内でクリックする）とセルの右上部にメニューアイコンが現れる。そのうちの真ん中のアイコン（利用可能なAI機能）をクリックすると、「コードを説明する」「コードの変換」などが選べる（3点メニュからも「コードを説明する」が選べます）
#
# 説明の依頼方法その２
# * 画面最下部中央の「Gemini」ボタンを押し、現れた対話窓に、上記の3行のプログラムをカットアンドペーストする（コピペする）と、このプログラムを初心者向けに丁寧に解説してくれます。Windowsの場合コピーのショートカットキーはCtrl+C（CtrlとCを同時に押す）、ペーストのショートカットはCtrl+Vです。Macでは、Windowsの「Ctrl」キーに相当するキーとして「Command」キーが使用されます。
#
# 続けて対話しよう
# * 応答が英語だった場合は、「日本語にして」などと入力すると、日本語に直してくれます。
# * **解説中に分からない点があったら、それについて質問**してみましょう。例：「変数って何ですか？」「デフォルトって何？」「浮動小数点？」
# 「代入について小学生でも分かるように教えて」
# * 初歩的なことを繰り返し繰り返し尋ねても、AIは根気よく教えてくれます。
# * こうやって**分かるまで繰り返し質問**することで、あなたの理解が深まります。これは、**生成AIならではの新しい勉強法**です。今まで初歩的なことでつまずいて恥ずかしくて、または、先生に遠慮して質問できずあきらめていた人でも、**一から勉強をやり直すことができます**。
#
# 算数も教えてもらえる？
# * Colab AI (Gemini)は、Pythonプログラムについてのチャットに特化されたAIですが、算数の問題の解説もプログラムを交えてしてくれる場合があります。算数や初歩の数学でつまずいている人は、生成AIでの勉強を試してみる価値があると思います。Colab AIが答えてくれない場合は、Colab外の生成AI（ChatGPT, Claudeなど）を使って下さい。
# * Colab AIに「1/2と1/3のどちらが大きいかを小学生に分かるように説明して」と入力してみましょう。

# %%
a = 2.4
b = 0.8
print(a + b, a / b)

# %% [markdown]
# ↑ **小数点以下を含む数を計算機で表現する（有限桁の2進数で表現する）と多くの場合、誤差（丸め誤差）を含む**ため、加減乗除の計算結果が上記のように誤差を含むことがそれなりの割合であります。← Gemini (Colab AI)で理由を尋ねても同様のことを教えてくれます。2進数について知りたい人は、Colab AIに「2進数について、小学生に分かるように教えて」「小数点以下を含む数の2進数表現について、小学生にも分かるように易しく、しかし、具体例を示しながら説明して下さい。」と頼んでみましょう。

# %% [markdown]
# 以下では、ざっくり要点のみ解説：
#
# - 10進数では、分母が10の累乗（1/10, 1/100 など）である小数がきれいに表現できます。たとえば、小数点以下2桁で表現するなら、1/100刻みの数だけが正確に表現できます。
# - 2進数では、分母が2の累乗（1/2, 1/4, 1/8 など）である小数がきれいに表現できます。たとえば、小数点以下10桁で表現するなら、1/1024 刻みの数だけが正確に表現できます。
# - 2進数と10進数では、このように刻み（正確に表現できる数）が違うので、両者の間で変換すると、多くの場合、丸め誤差が生じます。0.5 = 1/2 など、例外的に一致する（両方で正確に表現できる）ケースもあります。
# - 「一般的に、小数を2進数で表現すると、どれくらいの大きさの丸め誤差が生じるんだろう？」「小数点以下を含む数を四則演算するとどのくらいの頻度で結果に誤差が生じるのだろう？」と気になった人は、[この対話](https://chatgpt.com/share/692b05c1-771c-8004-b44a-21a2e609f997)を参照。
# - ↑ 10進1桁小数（0.1〜3.0）同士の演算のとき、a+bは約18%が誤差あり、a/bは約32%が誤差あり、といった実験結果が掲載されています。

# %% [markdown]
# ##演習問題１
# 以下のプログラムを実行して、実行時エラーが発生することを確認しましょう。
#
# エラーが出ると、Explain error（エラーの説明）ボタンやFix error（エラーの修正）ボタンが現れるのでそれを押してみましょう。

# %%
5 / 0

# %% [markdown]
# - エラーの説明だけで、コードの修正案を提示してこなかった場合は、「実行時エラーを避けるための修正をして」と頼むと修正してくれる
# - このエラーに対してGemini (Colab AI)が提案してきたコードの一例は下記のコードセルに掲載
# - try-exceptブロックについて知りたい人は、Geminiに尋ねて下さい
# - **コードの説明をAIに頼む**ときは、コードセルを選択した（コードセル内でクリックした）状態でセルの右上部に現れている3点メニューをクリックして、プルダウンメニューから「コードを説明する」をクリックするのが便利
# - コードセルを選択する（コードセル内でクリックする）とセルの右上部にメニューが現れる。メニュー中の5個のアイコンのうちの真ん中のアイコン（利用可能なAI機能）をクリックすると、「コードを説明する」「コードの変換」などが選べる（が、2025/11/30時点では、うまく動作しないことがあるようだ）

# %%
try:
    result = 5 / 0
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
    # Handle the error, e.g., assign a default value to the result
    result = float('inf')  # or any other appropriate value

print(result)

# %% [markdown]
# 下記のようなコードを提案してくることもあると思います。

# %%
denominator = 0
if denominator == 0:
    print("Division by zero is not allowed.")
else:
    result = 5 / denominator

# %% [markdown]
# 提案コード中のメッセージが英語だったので、新しいコードセルを作って、アンダーラインの付いた「生成」をクリックし、「printされる文を日本語にして」と入力し、「生成」ボタンを押した結果の出力の一例が下記：

# %%
# prompt: printされる文を日本語にして

print('ゼロ除算は許可されていません')

# %%
３＋６
# プログラム内のコメントや文字列以外の箇所に全角文字があると、Colabでは上のように、四角で囲んでマークされるので気づくことができる

# %% [markdown]
# ↑「**エラーの修正**」ボタンを押して提示された**提案を承認**するときは、チェックマークをクリック。**提案を拒否**するときは×印をクリック。

# %%
4 x 8

# %% [markdown]
# →メッセージが英語なのでチンプンカンプン→コピペして[DeepL](https://www.deepl.com/ja/translator)にお任せ！→さらに、[アプリ](https://www.deepl.com/ja/app/)をインストールしておくと、Ctrl-C Ctrl-Cで翻訳できて便利。または、スマホにGoogle翻訳アプリをインストールしておいて、アプリを起動し、カメラアイコンをタップし、スマホをかざして翻訳するのも便利。

# %% [markdown]
# # ４．ライブラリーのインポート

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# ↑これは何のおまじないなのでしょう？（以降のプログラムを実行するためには、その前に、このプログラムセルを実行しておく必要があります）
# * 疑問に思ったことは、Gemini (Colab AI)のチャットで尋ねる癖をつけて下さい。**プログラムをコピペしてチャット欄に貼り付けるだけ**です。
# * この勉強法は、これからプログラムやデータ分析を学ぶあなたの大きな力になることでしょう。

# %% [markdown]
# # ５．ヒストグラム：データ分析や機械学習の1ステップとして欠かせない可視化の一例として

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20
plt.hist(x, bins=20, range=(0, 100))

# %% [markdown]
# ↑このプログラムについても分からないことをGemini (Colab AI)で必ず尋ねて下さい
#
# * 「NameError: name 'np' is not defined」というエラーが出た場合は、「Explain error」ボタンを押すなどして、どのようなエラーで、何が原因かを理解し、解決してみて下さい。

# %% [markdown]
# ##演習問題２
#
# 1.   乱数のシードを変えてみよう。どうなりましたか？ 気づいたことをメモしておこう。皆さんがメモしたファイルは、**Googleドライブの [マイドライブ > Colab Notebooks] に自動保存**されています。「乱数のシード」って何？と思ったら、Gemini (Colab AI)に尋ねましょう。乱数のシードを変えるためにプログラムのどこをどう変えたらいいか分からないときもAIに尋ねましょう。上手に聞けばたいてい何でも教えてくれるよ。**生成AIはすごくたくさんのことを知っているけど、知りたいことをうまく聞き出すにはコツがいる**ので、いろいろ試行錯誤してみてね。コツを知りたい人は、[ここ](https://okana2ki.wordpress.com/llm-chatbot/#%E3%83%97%E3%83%AD%E3%83%B3%E3%83%97%E3%83%88-%E8%A8%80%E8%AA%9E%E7%94%9F%E6%88%90%E5%9E%8Bai%E3%81%B8%E3%81%AE%E3%83%86%E3%82%AD%E3%82%B9%E3%83%88%E5%85%A5%E5%8A%9B-%E3%81%AE%E6%9B%B8%E3%81%8D%E6%96%B9)を見て。
# > メモ：ここをダブルクリックして記入
#
# 2.   乱数の生成個数を多くしたり、少なくしたりしてみよう（やり方が分からないときはGemini (Colab AI)に聞いてね）。必要に応じてビンの数も変えて下さい。どうなりましたか？気づいたことをメモしておこう。
# > メモ：
#
# 3.   上の1.と2.の問題をGeminiに尋ねて解答させてみよう。どのように質問するとよいか、いろいろ工夫して下さい。あなたの工夫をメモしておこう。
# > メモ：
#
# 4.   あなたの答と、Geminiの答を比べて、気づいたことをメモしておこう。
# > メモ：
#
# 以上の演習問題1.から4.を解いたあなた。あなたはもう**生成AIで勉強する方法**（答を尋ねて丸写しするのでなく、**本当の力をつける方法**）を身につけたはず。その調子でがんばれば必ず道は開けるよ。

# %% [markdown]
# # ６．平均、中央値、最頻値、分散、標準偏差
# 母分散，標本分散，不偏分散，標準偏差については、[ここ](https://manabitimes.jp/math/1035)や[ここ](https://biolab.sakura.ne.jp/variance.html)を参照。要旨だけ記しておくと：
#
#
# *   母分散：全体の分布（母集団）の分散。未知数であることが多い。
# *   標本分散：標本（データ）の分散。$\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2$
# *   不偏標本分散（不偏分散）：標本分散を$\frac{n}{n-1}$倍したもの。$u^2=\dfrac{1}{n-1}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2$
# （ランダムサンプリングでは） 不偏分散の期待値は母分散と一致する。
# *   標本標準偏差：標本分散の平方根。$\sqrt{\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2}$
# *   不偏分散の平方根（これは母標準偏差に対する不偏推定量ではない）：$\sqrt{\dfrac{1}{n-1}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2}$

# %% [markdown]
# ##和を表す記号
# $\displaystyle\sum_{i=1}^n x_i = x_1+x_2+\cdots+x_n$
#
# 和の記号としてシグマを使うのは、和を表す英語sumの頭文字であるSと対応するギリシャ文字がΣだからです。
#
# 同様に、英語で積を表す単語がproductですから、その頭文字Pに対応するギリシャ文字Π（パイ）を用いて、積を表します。ちなみに、パイの小文字πは円周率を表しますが、これはギリシア語で周囲を表す「περίμετρος（= perimeter）」に由来しているそうです。

# %%
print(x.mean(), x.median()) # mean:平均, median:中央値
print(x.var(), x.var(ddof=0)) # var():不偏分散, var(ddof=0):標本分散
# pandasの標準設定では分散は不偏分散(ddof=1)。標本分散は(ddof=0)とする。
# （参考）numpyの標準設定では分散は標本分散。
print(x.std(), x.std(ddof=0)) # std():不偏分散の平方根, std(ddof=0):標本標準偏差

x.describe() # 記述統計量をまとめて生成。いくつか説明しておくと、std:不偏分散の平方根, 50%:中央値

# %%
y = [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 6]
pd.Series(y).mode() #最頻値を1次元配列で返す

# %% [markdown]
# ##演習問題３
# 以下のプログラムの実行結果はどのようになると思いますか？想像してから実行してみましょう。
# > あなたの予想をここに書きましょう。

# %%
x.mode()

# %%
x.round().mode()

# %%
plt.hist(x.round(), bins=100, range=(0, 100))

# %% [markdown]
# 予想通りでしたか？
# どうして、このような結果になったか分かりますか？
#
#
# > 分かったこと、気づいたことをここにメモしておきましょう。

# %% [markdown]
# # ７．プログラムを読んだり書いたりするときのTips（コツや小技のこと）
#
# *  round()というメソッドが何かを知りたいときは、コード中のroundにマウス・オン（マウス・オーバー）する（マウスカーソルをそこに持っていってしばらくそこに保つ）と、説明が表示されます。→説明が英語なのでチンプンカンプン→[DeepL](https://www.deepl.com/ja/translator)にお任せ！→さらに、[アプリ](https://www.deepl.com/ja/app/)をインストールしておくと、Ctrl-C Ctrl-Cで翻訳できて便利。Google翻訳アプリを起動したスマホをかざすのも便利。
#
# *  あるいは、「pandas round」でGoogle検索する(round()はpandasライブラリで使われるデータ構造のメソッドなので、このように検索)と解説が見つかります。これはround()に限らずプログラム中で分からないことがあった場合に共通して使える方法です。
#
# *  他には、たとえば「Python 平均」で検索すると、平均を求めるプログラムが見つかる、という方法もプログラムを書くときに役立ちます。
#
# * 2022年11月末に[ChatGPT](https://chat.openai.com/auth/login?next=/chat)が使えるようになったので、生成AIによるプログラム自動生成がとても強力です。たとえば、「Pythonで配列中のデータのヒストグラムを表示するプログラムを書いて」とか。[ChatGPT等の生成AI](https://okana2ki.wordpress.com/llm-chatbot/#%E8%A8%80%E8%AA%9E%E7%94%9F%E6%88%90%E5%9E%8Bai-%E3%83%81%E3%83%A3%E3%83%83%E3%83%88%E3%83%9C%E3%83%83%E3%83%88-%E3%81%AE%E4%BE%8B)を参照。また、2024年4月時点では、**Gemini**がColabの無料版で使えるので、Colab作業中はGeminiでチャットするのが手っ取り早いです。Colab内Geminiについては、[ここ](https://okana2ki.wordpress.com/llm-chatbot/#google-colab%E5%86%85%E3%81%AEgemini-colab-ai)にも使い方をまとめてあるよ。
#
# * **ChatGPTやGeminiに**例えば**「Pythonで平均を求めるプログラムを書いて」と頼む**と書いてくれます。Colab内でプログラム作成を頼むときは、新しいコードセルを作成し、表示された「コーディングを開始するか、AIで<u>生成</u>します。」中の「<u>生成</u>」をクリックすると、入力窓が現れるので、そこで依頼するのがお勧め。**教わったプログラム中で分からないことがあれば、それについて質問すると答えてくれるので理解が深まります。**答を丸写しするだけになってしまうのが心配な人は、（ChatGPTを使う必要がありますが）[Custom instructionsをAIチュータモードに設定](https://okana2ki.wordpress.com/llm-chatbot/#chatgpt-custom-instructions-%E3%82%AB%E3%82%B9%E3%82%BF%E3%83%A0%E6%8C%87%E7%A4%BA-%E3%81%AE%E4%BD%BF%E3%81%84%E6%96%B9-ai%E3%83%81%E3%83%A5%E3%83%BC%E3%82%BF%E7%94%A8)して使ってみて下さい。自分で考えるように促してくれるはず。
#
# * プログラム実行時にエラーメッセージが出てどうしたらいいか分からないときは、その**（プログラムと）エラーメッセージをコピペしてChatGPTやGeminiに尋ねる**と対処法を教えてくれます。
#
# * このノートブック中の（もちろんそれに限らず一般的に）分からないことや知りたいことがあれば、**ChatGPTやGeminiに尋ねる**と教えてくれます。たとえば、「np.random.seed(1) このプログラムについて初心者でも分かるように詳しく教えて。」その解説中に分からないことがあれば、さらに質問を繰り返して下さい。**あなた専用の優秀な家庭教師**として、どんな初歩的なことを聞き続けても親切に教えてくれます。
