# %% [markdown]
# <a href="https://colab.research.google.com/github/okana2ki/intro-to-DS/blob/main/DS10v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colabで開いたら、まず、↑上部の**「ドライブにコピー」をクリック**して下さい。Googleドライブの [マイドライブ > Colab Notebooks] に保存され、その後加えた変更がそこに自動保存されるようになります。
#
# ヘッダーに表示されるはずの「ドライブにコピー」が表示されてない場合は、画面上部右端の「v」アイコンをクリックして、ヘッダーの表示／非表示を切り替えて下さい。
#
# スマホの場合は、左上の3本線を押して、「ファイル」-「ドライブにコピーを保存」のはず。

# %% [markdown]
# # Gemini (Colab AI) の使い方
#
# * Googleアカウントでログインした状態で、**PCで**このコラボ・ノートブックを開くとAIが手伝ってくれます。
#
# * **スマホ**はGemini (Colab AI)に対応していませんが、Androidの場合は、ブラウザ画面右上部の「縦に3つ点が並んだメニューアイコン」をタップし、「**PC版サイト**」をタップすると、PC版表示になるため見にくくはなりますが、Geminiが使えます。iPhone, iPadの場合は[ここ](https://atmarkit.itmedia.co.jp/ait/articles/1411/10/news130.html)を見てPC版サイトへの切り替え方を調べて下さい。

# %% [markdown]
# ## コードの生成を依頼する
# ### 新しく作成したコードセルにコードを生成してもらう
#
# 1. 新しくコードセルを作成すると「コーディングを開始するか、AIで<u>生成</u>します。」と表示されるので、この「<u>生成</u>」のところをクリックする。
#
# 2. ノートブックの中央下部に対話窓が現れるので、生成して欲しいプログラムを言葉で指示すると、指示に沿ったコードがコードセル内に生成される。先頭に「－」が付いた赤地の行は削除される行を示し、先頭に「＋」が付いた緑地の行は追加される行を示す。
#
# 3. AIが提案してきたコードが良さそうであれば、対話窓の上の「承認して実行」をクリック；承認するだけなら「レ　許可」をクリック（その後、コードセルにマウスオンする（コードセル上にマウスカーソルを持ってくる）と左端に実行ボタンが現れるのでそれをクリックして実行）；受け入れない場合は「×　キャンセル」をクリック。
#
# 4. 実行エラーが出た場合に表示される「エラーの修正」ボタンを押すと修正案が提示される。「エラーの説明」ボタンを押すとエラーが説明される。
#
# 5. 対話用ウィンドウの右上部の「×」を押すと対話ウィンドウを消すことができる；右上部の「パネルに移動」アイコンを押すと、対話ウィンドウは閉じられ、右側に対話パネルが開く；右上の３点メニューを開いて「新しいチャット」を始めることもできる。
#
# 6. 右側の対話パネルの右上の「ノートブックに移動」アイコンを押すと、対話パネルは閉じられ、ノートブックの中央下部に対話ウィンドウが開く。
#
# ### 今選択されているセルのすぐ下にコードセルを作って、そこにコードを生成してもらう
#
# 1. 画面最下部中央の「Gemini」アイコンをクリックする。
#
# 2. 対話ウインドウまたは対話パネルが開くので、コード生成を依頼する。その時点で選択されているセルのすぐ下にコードセルが作られ、そこにコードが生成される。（以降は、上記と同じなので省略）

# %% [markdown]
# ## コードの修正を依頼する
#
# 1. 修正したいコードセルを選択（コードセル内でクリック）
# 2. 右上に現れたメニューアイコンの真ん中のアイコン（利用可能なAI機能）を選択
# 3. プルダウンメニューから「コードの変換」を選択
# 4. 対話窓に文脈が設定される（変更したいセルの先頭が一番上に表示される）ので、対話窓に変更したい内容を入力
# 5. 送信アイコン（紙飛行機アイコン）をクリック
# 6. コード中の削除される行の先頭に「－」がついて赤地になる。挿入される行の先頭には「＋」がついて緑地になる。この変更内容を確認して、採用する場合、対話窓中の「承認して実行」か「レ　許可」を押す。変更を拒否する場合は、「×　キャンセル」を押す。

# %% [markdown]
# ## コードの説明を依頼する
#
# ### 説明の依頼方法その１
# * コードセルを選択する（コードセル内でクリックする）とセルの右上部にメニューアイコンが現れる。そのうちの真ん中のアイコン（利用可能なAI機能）をクリックすると、「コードを説明する」「コードの変換」などが選べる（3点メニュからも「コードを説明する」が選べます）
#
# ### 説明の依頼方法その２
# * 画面最下部中央の「Gemini」ボタンを押し、現れた対話窓に、上記の3行のプログラムをカットアンドペーストする（コピペする）と、このプログラムを初心者向けに丁寧に解説してくれます。Windowsの場合コピーのショートカットキーはCtrl+C（CtrlとCを同時に押す）、ペーストのショートカットはCtrl+Vです。Macでは、Windowsの「Ctrl」キーに相当するキーとして「Command」キーが使用されます。
#
# ### 続けて対話しよう
# * 応答が英語だった場合は、「日本語にして」などと入力すると、日本語に直してくれます。
# * **解説中に分からない点があったら、それについて質問**してみましょう。例：「変数って何ですか？」「デフォルトって何？」「浮動小数点？」
# 「代入について小学生でも分かるように教えて」
# * 初歩的なことを繰り返し繰り返し尋ねても、AIは根気よく教えてくれます。
# * こうやって**分かるまで繰り返し質問**することで、あなたの理解が深まります。これは、**生成AIならではの新しい勉強法**です。今まで初歩的なことでつまずいて恥ずかしくて、または、先生に遠慮して質問できずあきらめていた人でも、**一から勉強をやり直すことができます**。

# %% [markdown]
# # ライブラリーのインポート
# コラボノートを立ち上げたら、または、ランタイムに接続し直したら、下記のコードセルを実行する必要があります。「先週実行したから、今回は実行不要」ということはありません。
#
# **下記のコードセルを選択して、Geminiに説明してもらいましょう。**

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# # ヒストグラム：データ分析や機械学習の1ステップとして欠かせない可視化の一例として（再掲）
#
# **下記のコードセルを選択して、Geminiに説明してもらいましょう。**

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20
plt.hist(x, bins=20, range=(0, 100))

# %% [markdown]
# **上記のコードセルを実行してみよう。** コードセルにマウスオンして、左上に現れた再生ボタンを押すと実行できます。
#
# - **「NameError: name 'np' is not defined」というエラーが出た場合**は、「エラーの説明」ボタンを押すなどして、どのようなエラーで、何が原因かを理解し、解決してみて下さい。

# %% [markdown]
# ## 演習問題２（再掲）
#
# 1.   乱数のシードを変えてみよう。どうなりましたか？ 気づいたことをメモしておこう。皆さんがメモしたファイルは、**Googleドライブの [マイドライブ > Colab Notebooks] に自動保存**されています。「乱数のシード」って何？と思ったら、Gemini (Colab AI)に尋ねましょう。乱数のシードを変えるためにプログラムのどこをどう変えたらいいか分からないときもAIに尋ねましょう。上手に聞けばたいてい何でも教えてくれるよ。**生成AIはすごくたくさんのことを知っているけど、知りたいことをうまく聞き出すにはコツがいる**ので、いろいろ試行錯誤してみてね。コツを知りたい人は、[ここ](https://okana2ki.wordpress.com/llm-chatbot/#%E3%83%97%E3%83%AD%E3%83%B3%E3%83%97%E3%83%88-%E8%A8%80%E8%AA%9E%E7%94%9F%E6%88%90%E5%9E%8Bai%E3%81%B8%E3%81%AE%E3%83%86%E3%82%AD%E3%82%B9%E3%83%88%E5%85%A5%E5%8A%9B-%E3%81%AE%E6%9B%B8%E3%81%8D%E6%96%B9)を見て。
# > メモ：ここをダブルクリックして記入
#
# 2.   乱数の生成個数を多くしたり、少なくしたりしてみよう（やり方が分からないときはGemini (Colab AI)に聞いてね）。必要に応じてビンの数も変えて下さい。どうなりましたか？気づいたことをメモしておこう。
# > メモ：

# %% [markdown]
# ## 演習問題２（再掲：つづき）
#
# 3.   上の1.と2.の問題をGeminiに尋ねて解答させてみよう。コードの変更を言葉で頼むこともできるし、変更により何がどう変わるかを尋ねることもできます。どのように質問するとよいか、いろいろ工夫して下さい。あなたの工夫をメモしておこう。
# > メモ：
#
# 4.   あなたの答と、Geminiの答を比べて、気づいたことをメモしておこう。
# > メモ：
#
# 以上の演習問題1.から4.を解いたあなた。あなたはもう**生成AIで勉強する方法**（答を尋ねて丸写しするのでなく、**本当の力をつける方法**）を身につけたはず。その調子でがんばれば必ず道は開けるよ。

# %% [markdown]
# ## 演習問題２の3.解説
#
# AIへの依頼の一例：「乱数のシードを変えて下さい。」
#
# ↓ 下記のコードセルを選択し、変更を依頼してみよう！！

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20
plt.hist(x, bins=20, range=(0, 100))

# %% [markdown]
# ## 解説つづき
#
# 次に、シードによる変化をより分かりやすく可視化してみよう。どのように依頼したらいいでしょうか？
#
# ↓ 下のコードセルで依頼してみよう！！

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20
plt.hist(x, bins=20, range=(0, 100))

# %% [markdown]
# ↓ 可視化の例を２つ示します。

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20; 透明度0.5
plt.hist(x, bins=20, range=(0, 100), alpha=0.5, label='x')
np.random.seed(2) # 別のシードをセット
y = pd.Series(np.random.normal(50, 10, 100))
plt.hist(y, bins=20, range=(0, 100), alpha=0.5, label='y')
plt.legend(loc='upper left')
plt.show()

# %%
np.random.seed(1)
x = pd.Series(np.random.normal(50, 10, 100))
y = pd.Series(np.random.normal(50, 10, 100)) # 続きで乱数を発生するので別の系列になる
# ヒストグラムを描画；ビンの数20；並べて表示
plt.hist([x,y], bins=20, range=(0, 100), label=['x','y'])
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 解説つづき
#
# 次に、乱数の生成個数を多くしたり、少なくしたりしてみよう。必要に応じてビンの数も変えて下さい。
#
# ↓ 自分でできる人は下のコードセルに自分でコードを書いて下さい。分からない人は下のコードセルで依頼してみよう！！

# %%
# 乱数のシードをセット
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を100個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 100))
print(x)
# ヒストグラムを描画；ビンの数20
plt.hist(x, bins=20, range=(0, 100))

# %% [markdown]
# ↓ 以下の４つは、乱数の生成個数を変えて変化を見た例です。ビンの数も調整しています。

# %%
np.random.seed(1)
x = pd.Series(np.random.normal(50, 10, 20)) # 少なくしてみる
y = pd.Series(np.random.normal(50, 10, 20))
plt.hist(x, bins=20, range=(0, 100), alpha=0.5, label='x')
plt.hist(y, bins=20, range=(0, 100), alpha=0.5, label='y')
plt.legend(loc='upper left')
plt.show()

# %%
np.random.seed(1)
x = pd.Series(np.random.normal(50, 10, 10000)) # 多くしてみる
y = pd.Series(np.random.normal(50, 10, 10000))
plt.hist(x, bins=20, range=(0, 100), alpha=0.5, label='x')
plt.hist(y, bins=20, range=(0, 100), alpha=0.5, label='y')
plt.legend(loc='upper left')
plt.show()

# %%
np.random.seed(1)
x = pd.Series(np.random.normal(50, 10, 10000))
y = pd.Series(np.random.normal(50, 10, 10000))
plt.hist(x, bins=200, range=(0, 100), alpha=0.5, label='x') # ビンの数を増やしてみる
plt.hist(y, bins=200, range=(0, 100), alpha=0.5, label='y')
plt.legend(loc='upper left')
plt.show()

# %%
np.random.seed(1)
x = pd.Series(np.random.normal(50, 10, 1000000)) # もっと多くしてみる
y = pd.Series(np.random.normal(50, 10, 1000000))
plt.hist(x, bins=200, range=(0, 100), alpha=0.5, label='x')
plt.hist(y, bins=200, range=(0, 100), alpha=0.5, label='y')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #平均、中央値、最頻値；分散、標準偏差
# **平均、中央値（昇順に並べたとき中央にくる値；中央値は外れ値に対して頑健）、最頻値（最も出やすい値）は、代表値（１つの値でデータを代表させる）。分散と標準偏差は、ばらつきの指標。**
#
# 母分散，標本分散，不偏分散，標準偏差については、[ここ](https://manabitimes.jp/math/1035)や[ここ](https://biolab.sakura.ne.jp/variance.html)を参照。要旨だけ記しておくと：
#
#
# *   母分散：全体の分布（母集団）の分散。未知数であることが多い。
# *   標本分散 sample variance（[日本の統計学の分野では標本分散を不偏分散を指す言葉として使うことが多く混乱](https://sgul.repo.nii.ac.jp/record/1807/files/SK-1-001.pdf)する。これを避けるため標本分散を単に分散と呼ぶとよいという説も；英語の場合はsample varianceと言えば紛れはない）：標本（データ）の**分散（ばらつきの指標）**。「(平均からの偏差)の2乗」の平均。$\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2$
# *   不偏標本分散 unbiased sample variance（不偏分散）：標本分散を$\frac{n}{n-1}$倍したもの。$u^2=\dfrac{1}{n-1}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2$
# （ランダムサンプリングでは） 不偏分散の期待値は母分散と一致する。日本の統計学の分野では不偏分散を標本分散と呼ぶことが多いので要注意。
# *   標本**標準偏差**：標本分散の平方根。$\sqrt{\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2}$
# *   不偏分散の平方根（これは母標準偏差に対する不偏推定量ではない）：$\sqrt{\dfrac{1}{n-1}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2}$

# %% [markdown]
# ##和を表す記号
# $\displaystyle\sum_{i=1}^n x_i = x_1+x_2+\cdots+x_n$
#
# 和の記号としてシグマを使うのは、和を表す英語sumの頭文字であるSと対応するギリシャ文字がΣだからです。
#
# 同様に、英語で積を表す単語がproductですから、その頭文字Pに対応するギリシャ文字Π（パイ）を用いて、積を表します。ちなみに、パイの小文字πは円周率を表しますが、これはギリシア語で周囲を表す「περίμετρος（= perimeter）」に由来しているそうです。

# %% [markdown]
# **↓ 下の2つのコードセルのコードの説明を依頼しよう。**
#
# **↓ コードが理解できたら実行してみよう。**

# %%
np.random.seed(1)
# 平均 50, 標準偏差 10 の正規乱数を1000個生成してpandasの1次元配列xに入れる
x = pd.Series(np.random.normal(50, 10, 1000))

print(x.mean(), x.median())  # mean:平均, median:中央値
print(x.var(), x.var(ddof=0))  # var():不偏分散, var(ddof=0):標本分散
# pandasの標準設定では分散は不偏分散(ddof=1)。標本分散は(ddof=0)とする。
# （参考）numpyの標準設定では分散は標本分散。
print(x.std(), x.std(ddof=0))  # std():不偏分散の平方根, std(ddof=0):標本標準偏差

x.describe()  # 記述統計量をまとめて生成。いくつか説明しておくと、std:不偏分散の平方根, 50%:中央値

# %%
y = [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 6]
pd.Series(y).mode()  # 最頻値を1次元配列で返す

# %% [markdown]
# ## 演習問題３（再掲）
# 以下のプログラムの実行結果はどのようになると思いますか？想像してから実行してみましょう。
# > あなたの予想をここに書きましょう。
#
# コードが分からなくて結果が想像できない場合は、まず、コードの説明を依頼して下さい。

# %%
x.mode()

# %%
x.round().mode()

# %%
plt.hist(x.round(), bins=100, range=(0, 100))

# %% [markdown]
# 予想通りでしたか？
# どうして、このような結果になったか分かりますか？
#
#
# > メモ：
# *   x.mode()は、全ての値がバラバラだったので、全てが最頻値（1回ずつ出現）となった。
# *   x.round().mode()は、四捨五入されたため、48の頻度が最大になった。

# %% [markdown]
# # プログラムを読んだり書いたりするときのTips（コツや小技のこと）
#
# *  【旧情報】round()というメソッドが何かを知りたいときは、コード中のroundにマウス・オン（マウス・オーバー）する（マウスカーソルをそこに持っていってしばらくそこに保つ）と、説明が表示されます。→説明が英語なのでチンプンカンプン→[DeepL](https://www.deepl.com/ja/translator)にお任せ！→さらに、[アプリ](https://www.deepl.com/ja/app/)をインストールしておくと、Ctrl-C Ctrl-Cで翻訳できて便利。Google翻訳アプリを起動したスマホをかざすのも便利。（今は、生成AIに尋ねるのが手っ取り早いです）
#
# *  【旧情報】あるいは、「pandas round」でGoogle検索する(round()はpandasライブラリで使われるデータ構造のメソッドなので、このように検索)と解説が見つかります。これはround()に限らずプログラム中で分からないことがあった場合に共通して使える方法です。（生成AIが使えなかった時代は、このようにしていました。今は生成AIに尋ねるのが手っ取り早い）
#
# *  【旧情報】他には、たとえば「Python 平均」で検索すると、平均を求めるプログラムが見つかる、という方法もプログラムを書くときに役立ちます。（生成AIが使えなかった時代は、このようにしていました）
#
# * 2022年11月末に[ChatGPT](https://chat.openai.com/auth/login?next=/chat)が使えるようになったので、生成AIによるプログラム自動生成がとても強力です。たとえば、「Pythonで配列中のデータのヒストグラムを表示するプログラムを書いて」とか。
#
# * また、2025年12月時点では、GeminiがColabの無料版で使えるので、**Colab作業中はGeminiに依頼したり、チャットするのが手っ取り早い**です。
#
# * **ChatGPTやGeminiに**例えば**「Pythonで平均を求めるプログラムを書いて」と頼む**と書いてくれます。**教わったプログラム中で分からないことがあれば、それについて質問すると答えてくれるので理解が深まります。**
#
# * 答を丸写しするだけになってしまうのが心配な人は、ChatGPTの場合は、対話窓の「＋」を押して、選択メニューから「**あらゆる学びをサポート**」モードを選んで使ってみて下さい。自分で考えるように促してくれるはず。**colab環境でも同様**の使い方ができます。追々やりかたを伝えます。他にも、**クイズを出してもらって**、理解を確認しながら勉強をすすめることもできます。このやり方も追々伝えます。
#
# * プログラム実行時にエラーメッセージが出てどうしたらいいか分からないときは、その**（プログラムと）エラーメッセージをコピペしてChatGPTやGeminiに尋ねる**と対処法を教えてくれます。
#
# * このノートブック中の（もちろんそれに限らず一般的に）分からないことや知りたいことがあれば、**ChatGPTやGeminiに尋ねる**と教えてくれます。たとえば、「np.random.seed(1) このプログラムについて初心者でも分かるように詳しく教えて。」その解説中に分からないことがあれば、さらに質問を繰り返して下さい。**あなた専用の優秀な家庭教師**として、どんな初歩的なことを聞き続けても親切に教えてくれます。

# %% [markdown]
# ---

# %% [markdown]
# #本日の内容

# %% [markdown]
# #相関係数（と散布図）
# $相関係数 = \dfrac{xとyの共分散}{xの標準偏差 \times yの標準偏差}$
#
# $相関係数 = \dfrac{\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})(y_i-\overline{y})}{\sqrt{\dfrac{1}{n}\displaystyle\sum_{i=1}^n(x_i-\overline{x})^2}\sqrt{\dfrac{1}{n}\displaystyle\sum_{i=1}^n(y_i-\overline{y})^2}}$

# %% [markdown]
# ## xy平面上にランダムに生成した10個の点を散布図として表示し、xとyの相関係数を求めるコード

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = pd.Series(np.random.uniform(0, 5, 10))  # 0以上5未満の一様乱数を10個
y = pd.Series(np.random.uniform(0, 5, 10))
plt.xlim(0,5)  # 表示範囲
plt.ylim(0,5)
plt.scatter(x,y)  # 散布図
plt.show()
res = x.corr(y)  # 相関係数
print(res)

# %% [markdown]
# ## 演習問題４
# 1.   上のプログラムを何回か実行して、データの分布と相関係数の関係を体感しよう。
# 2.   相関が強い（１かー１に近い）ケースの散布図と相関係数を記録して残したいと思ったら、どうすればよいと思いますか？　ヒント：**体力勝負でひたすら何回も試してもいいのですが、そのためのプログラムを書くと楽ちん**ですね。自分でプログラムが書ける人はぜひ書いてみて下さい。自分では書けない人も生成AIに相談すると簡単に書けますよ。

# %% [markdown]
# # 相関係数行列と散布図行列

# %% [markdown]
# ## 演習問題5
#
# AIに頼んで相関係数行列と散布図行列を作成してみよう。どのように依頼しますか？
#
# 以下は、依頼した結果のコードと、そのコードの説明（これも自動生成）の一例です。

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 日本語フォントの設定
# Colabで利用可能な日本語フォントの例: 'IPAexGothic', 'Noto Sans CJK JP'
# !pip install japanize-matplotlib # japanize-matplotlibをインストール
import japanize_matplotlib # 日本語表示のためにインポート

# データの生成
np.random.seed(42) # 再現性のためにシードを設定
data = {
    'Feature_A': np.random.rand(100) * 10,
    'Feature_B': np.random.rand(100) * 5 + np.random.rand(100) * 2,
    'Feature_C': np.random.rand(100) * 3 + np.random.rand(100) * 7,
    'Feature_D': np.random.randn(100) * 2 + 5
}
df = pd.DataFrame(data)

print("--- データフレームの最初の5行 ---")
display(df.head())

# 相関係数行列の計算と表示
correlation_matrix = df.corr()
print("\n--- 相関係数行列 ---")
display(correlation_matrix)

# 相関係数行列のヒートマップ表示
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('相関係数行列のヒートマップ')
plt.show()

# 散布図行列の生成と表示
print("\n--- 散布図行列 ---")
sns.pairplot(df)
plt.suptitle('散布図行列', y=1.02) # タイトルを少し上に配置
plt.show()

# %% [markdown]
# ### コードの説明:
#
# 1.  **`import`文**: `pandas`、`numpy`、`seaborn`、`matplotlib.pyplot`をインポートしています。
# 2.  **データフレームの作成**: `numpy.random.rand`と`numpy.random.randn`を使用して、4つの特徴量（`Feature_A`、`Feature_B`、`Feature_C`、`Feature_D`）を持つ100行のサンプルデータを生成し、`pandas.DataFrame`を作成しています。`np.random.seed(42)`で乱数のシードを設定することで、コードを再度実行したときに同じ結果が得られるようにしています。
# 3.  **相関係数行列**: `df.corr()`メソッドを使って、データフレーム内の各特徴量間のピアソン相関係数を計算し、相関係数行列を生成しています。相関係数行列は`display()`で表示しています。
# 4.  **相関係数行列のヒートマップ**: `seaborn.heatmap()`関数を使って、計算した相関係数行列を視覚的に分かりやすいヒートマップとして表示しています。`annot=True`で各セルに相関係数の値を表示し、`cmap='coolwarm'`で色のグラデーションを設定しています。
# 5.  **散布図行列**: `seaborn.pairplot(df)`を使って、データフレーム内のすべての数値変数間の散布図行列を生成しています。対角線には各変数の分布（ヒストグラムまたはKDE）が表示され、非対角線には変数間の散布図が表示されます。これにより、変数間の関係性（線形関係、非線形関係、外れ値など）を一度に視覚的に確認できます。

# %% [markdown]
# # おまけ：3次元散布図
# 残念ながらColabで下記のプログラムを実行してもドラッグでグリグリ回せる3次元プロットは表示されません。
#
# 回せる3次元プロットを表示するためには、Google Colabではなく、自分のパソコンにPythonをインストールして、Pythonインタプリタで下記のプログラムを実行する必要があります。
#
# まず、PythonとVisual Studio Codeをインストールして下さい（すでにインストール済みの人は、vscodeで下記のPythonプログラムを実行して下さい）。たとえば、[ここ](https://sites.google.com/view/genai4e/%E7%94%9F%E6%88%90ai%E5%88%A9%E7%94%A8%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0/vibe-coding%E9%A2%A8%E6%BC%94%E7%BF%92)を参照。この他にも、「python vscode インストール」「python インストール」「vscode インストール」などと検索すると有用なサイトがいろいろあります。Pythonインストール時の注意：自動で環境変数にパスを追加するため、「Add Python x.x to PATH」にチェックを入れ、「Install Now」をクリックします。vscodeで下記のPythonプログラムを実行すると、ぐりぐり回せる3次元散布図が表示されます。
#
# 別の方法としては、たとえば、[このサイト](https://www.javadrive.jp/python/install/index5.html)にしたがって、Anacondaをインストールして、Anaconda Prompt(Anaconda3)からPythonインタプリタを起動し、下記のプログラムを実行すると、ぐりぐり回せます。

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [1, 2, 3, 4, 5]
y = [1, 8, 3, 6, 5]
z = [1, 5, 3, 8, 9]

ax.scatter(x, y, z)
plt.show()

# %% [markdown]
# # Gemini (Colab AI)におけるシステム指示（カスタム指示）
#
# Gemini (Colab AI)では、システム指示（カスタム指示）の設定ができないので、AIチュータモードにはできないと思っていたのですが、**システム指示と同様の効果をコラボノート内で得る方法**を思いついたので、このノートブックで試してみました！コードセル中に書いた以下のコードがその一例です：
#
# 同様に、コード生成を依頼されても、すぐにはコードは生成せずに、対話を通してコードを共同で作成するようにもできるはず。いろいろなシステム指示を試してみて下さい。

# %%
# system instruction:
# ユーザはプログラミング初心者です。
# あなたの役割は、ユーザのコーディング依頼に応じる際、ユーザがプログラミングを習得できるようにすることです。
# ユーザのコーディング依頼に対してコードを生成する場合、依頼されたコードの実行後に、
# 「Pythonコードの書き方に関してユーザは何が分かってないかを自覚させるクイズ」を出題するコードを生成して下さい。
# クイズの解答に応じてユーザにフィードバックするコードも追加して下さい。

# %% [markdown]
# - このコードセルより下では、GeminiがAIチュータをやってくれるはず！
#
# - なお、上記のシステム指示を記したセルより上でコード生成を依頼した場合は、Geminiは普通に応答します。ただし、一度、このシステム指示が読み込まれると、その後は、コードセルの位置に関わらず、システム指示が有効になります。無効にするには、3点メニューから「新しいチャット」を選択して、チャットをリセットする必要があります。
#
# - 下記のコードセルで何か生成を依頼してみて下さい。

# %% [markdown]
# 以下は、演習問題５を依頼した際、自動生成されたものです。そのまま残しておきます。

# %% [markdown]
# # Task
# Generate Python code in the current cell to create a DataFrame, then compute and display its correlation matrix and scatter plot matrix.

# %% [markdown]
# ## Python_engineer
#
# ### Subtask:
# ユーザーが指定したセルに、データフレームを作成し、その相関係数行列と散布図行列を生成するPythonコードを記述します。

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The process successfully generated Python code to create a DataFrame.
# *   The generated code includes functionality to compute and display the correlation matrix for the DataFrame variables.
# *   The code also provides the capability to generate and display a scatter plot matrix, offering a visual representation of relationships between variables.
#
# ### Insights or Next Steps
# *   The next step involves executing the generated Python code to produce the DataFrame, its correlation matrix, and the scatter plot matrix.
# *   Once executed, the correlation matrix will quantify linear relationships, while the scatter plot matrix will visually represent pairwise relationships and distributions, which can then be used for further data analysis.
